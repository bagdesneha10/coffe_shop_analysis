# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import numpy as nb
df=pd.read_csv("../Practice/CoffeeShopSales-cleaned (1).csv")
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df['Month']=df.transaction_date.str[-5:-3]

# %%
sb.countplot(df.store_location)
sb.countplot(df.product_category)
# Out:
# <Axes: xlabel='count', ylabel='store_location'>

# %%
sb.countplot(df.product_category)
# Out:
# <Axes: xlabel='count', ylabel='product_category'>

# %%
sb.countplot(df.store_location)
# Out:
# <Axes: xlabel='count', ylabel='store_location'>

# %%
sb.countplot(df.product_type)
plt.xticks(rotation=90)
plt.show()

# %%
sb.countplot(df.weekday)
# Out:
# <Axes: xlabel='count', ylabel='weekday'>

# %%
sb.lineplot(x=df.weekday,y=df.total_amount)
plt.xticks(rotation=90)
plt.show()

# %%
sb.lineplot(x=df.Month,y=df.total_amount)
# Out:
# <Axes: xlabel='Month', ylabel='total_amount'>

# %% [markdown]
# df.groupby('Month')['total_amount']

# %%
sb.histplot(df.total_amount)
# Out:
# <Axes: xlabel='total_amount', ylabel='Count'>

# %%
sb.histplot(df.transaction_qty)
# Out:
# <Axes: xlabel='transaction_qty', ylabel='Count'>

# %%
sb.histplot(df.unit_price)
# Out:
# <Axes: xlabel='unit_price', ylabel='Count'>

# %%
sb.pointplot(x=df.total_amount,y=df.product_category)
# Out:
# <Axes: xlabel='total_amount', ylabel='product_category'>

# %%
sb.pointplot(x=df.total_amount,y=df.store_location)
# Out:
# <Axes: xlabel='total_amount', ylabel='store_location'>

# %%
sb.violinplot(df.total_amount)
# Out:
# <Axes: ylabel='total_amount'>

# %%
sb.violinplot(df.unit_price)
# Out:
# <Axes: ylabel='unit_price'>

# %%
sb.scatterplot(x=df.unit_price,y=df.transaction_qty)
# Out:
# <Axes: xlabel='unit_price', ylabel='transaction_qty'>

# %%
sb.kdeplot(df.total_amount)
# Out:
# <Axes: xlabel='total_amount', ylabel='Density'>

# %%
sb.kdeplot(df.transaction_qty)
# Out:
# <Axes: xlabel='transaction_qty', ylabel='Density'>

# %%
sb.jointplot(x=df.unit_price,y=df.total_amount)
plt.xticks(rotation=90)
plt.yticks(rotation=90)
plt.show()

# %%
sb.jointplot(x=df.transaction_qty,y=df.total_amount)

# %%
plt.figure(figsize=(7,8))
sales_distribution=df.groupby('product_category')['total_amount'].sum()
plt.pie(sales_distribution.values,labels=sales_distribution.index,autopct='%d%%')
startangle=90
plt.show()

# %%
sales_distribution=df.groupby('store_location')['total_amount'].sum()
plt.pie(sales_distribution.values,labels=sales_distribution.index,autopct='%d%%')
plt.show()

# %%
weekend_sales_share=df.groupby('weekday')['total_amount'].sum()
plt.pie(weekend_sales_share.values,labels=weekend_sales_share.index,autopct='%d%%')
plt.show()

# %% [markdown]
# sb.swarmplot(df.transaction_qty)
# plt.show()

# %% [markdown]
# sb.swarmplot(df.unit_price)

# %% [markdown]
# a=[ 'Unit_Price', 'Total_amount', 'Transaction_qty']
# sb.pairplot(df[a],diag_kind='kde',plot_kws={'alpha'=0.6,'s'=6})
# plt.show()

# %%
total_sales=unit_price*transaction_qty
sb.striplot(x=df.total_sales,y=df.product_category)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 total_sales=unit_price*transaction_qty
#       2 sb.striplot(x=df.total_sales,y=df.product_category)
#       3 plt.show()
#
# NameError: name 'unit_price' is not defined

# %%
df
# Out:
#         transaction_id transaction_date transaction_time  transaction_qty  \
# 0                    1       2023-01-01         07:06:11                2
# 1                    2       2023-01-01         07:08:56                2
# 2                    3       2023-01-01         07:14:04                2
# 3                    4       2023-01-01         07:20:24                1
# 4                    5       2023-01-01         07:22:41                2
# ...                ...              ...              ...              ...
# 149111          149452       2023-06-30         20:18:41                2
# 149112          149453       2023-06-30         20:25:10                2
# 149113          149454       2023-06-30         20:31:34                1
# 149114          149455       2023-06-30         20:57:19                1
# 149115          149456       2023-06-30         20:57:19                2
#
#         store_id   store_location  product_id  unit_price    product_category  \
# ...

# %%
df.dtypes
# Out:
# transaction_id        int64
# transaction_date     object
# transaction_time     object
# transaction_qty       int64
# store_id              int64
# store_location       object
# product_id            int64
# unit_price          float64
# product_category     object
# product_type         object
# product_detail       object
# total_amount        float64
# week                 object
# weekday              object
# transaction_hour      int64
# Month                object
# dtype: object

# %%
df.product_category.value_counts()
total_sales=df.groupby('product_category')['total_amount'].sum()
sb.stripplot(total_sales)
# Out:
# <Axes: ylabel='total_amount'>
